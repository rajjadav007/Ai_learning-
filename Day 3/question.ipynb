# %% [markdown]
# Check whether a number is positive, negative, or zero

# %%
number=float(input("eisnter the number"))

if number>0:
    print ("the number is positive",number)
elif number <0:
    print ("the number is negative",number)
else:
    print ("the number is zero",number)
# Out:
# the number is positive 21.0

# %% [markdown]
# Check even or odd

# %%
num=int(input("enter the number"))

if num % 2:
    print ("the number is odd")
else:
    print ("the number is even")
# Out:
# the number is even

# %% [markdown]
# Find the greater of two numbers

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))

if a>b:
    print ("a greater number")
elif a<b:
    print ("b is greater")
else :
    print ("both are equal")
# Out:
# both are equal

# %% [markdown]
# Find the greatest of three numbers

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
c=int(input("enter the third number"))

if a>b and a>c:
    print ("a is greater number")
elif b>c and b>a:
    print ("b is greater number")
else:
    print ("c is greater number")
# Out:
# c is greater number

# %% [markdown]
# Check whether a person is eligible to vote

# %%
age=int(input("enter the age "))

if age<18:
    print ("you are not eligible for the vote")
else:
    print ("you are eligible ")
# Out:
# you are eligible

# %% [markdown]
# Student pass/fail

# %%
maths=int(input("enter the maths marks"))
science=int(input("enter the science marks"))
history=int(input("enter the history marks"))

marks=maths+science+history

if marks>80:
    print ("you are pass")
else:
    print ("you are fail")
# Out:
# you are pass

# %% [markdown]
# Student grade calculator

# %%
maths=int(input("enter the maths marks"))
science=int(input("enter the science marks"))
history=int(input("enter the history marks"))
java=int(input("enter the java marks"))

marks=maths+science+history+java

if marks>=80:
    print ("your grade is A")
elif marks>=60:
    print ("your grade is B")
elif marks>=50:
    print ("your grade is c")
else:
    print ("you are fail ")
# Out:
# you are fail

# %% [markdown]
# Check whether a year is a leap year

# %%
year=int(input("enter the year"))

if year %400==0:
    print ("this year is leap year")
elif year %100==0:
    print ("this year is not leap year")
elif year %4==0:
    print ("this year is  leap year")
else:
    print ("this year is not leap year")
# Out:
# this year is not leap year

# %% [markdown]
# Simple login system

# %%
username=str(input("enter the username"))
password=str(input("enter the username"))

print ("you are sucessfully sign up ")

user_name=str(input("enter the username"))
user_pass=str(input("enter the passworkd"))

if username==user_name and password==user_pass:
    print ("you are login")
else:
    print ("you are not login ")
# Out:
# you are sucessfully sign up
# you are login

# %% [markdown]
# Electricity bill calculator using conditions

# %%
bill=int(input("enter the bill uint"))

if bill<=100:
    unites=bill*5
elif bill<=200:
     unites=bill*7
elif bill<250:
     unites=bill*8
elif bill<300:
     unites=bill*10
else:
    unites=bill*15

print ("your electricity bill is",unites)
# Out:
# your electricity bill is 707
