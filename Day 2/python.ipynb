# %%
a=int(input("enter the marks1"))
b=int(input("enter the marks 2"))

marks=(a+b)

if marks>80:
    print ("your grade is A")
elif marks>60:
    print ("your grade B")
else:
    print ("you are fail")
# Out:
# your grade is A
